# %% [markdown]
# ## ECHR Dataset - Component Classification results
#
# This notebook contains functions to measure the performance of a classifier applied over a set of annotations.
#
# The output of the classification files is expected to be compatible with the output of the UKPLab models. Each line contains the token, the true label, and predicted label of one classification example, in that order, separated by tabs. The first row has the columns names. For example:
#
# `word_n    I-Premise:2:Support    I-Premise:-1:Support`
#
# Training results must be stored in tsv format with the following columns: epoch, modelName, dev_score, test_score, max_dev_score, max_test_score

# %%
# %matplotlib inline
import numpy
import matplotlib.pyplot as plt
import pandas
import pickle
import os
import re
import seaborn as sns
from sklearn import metrics

import colors
import learning_metrics
import performance_metrics
import visualizations

# %%
import importlib
importlib.reload(colors)
importlib.reload(learning_metrics)
importlib.reload(performance_metrics)
importlib.reload(visualizations)
# Out:
# <module 'visualizations' from '/home/mteruel/am/argument_mining/evaluation/visualizations.py'>

# %%
CC_EXPERIMENTS_DIRS = [
        '../../results/echr/claim_detection/sentence/19-12-12-11-36',
    '../../results/echr/claim_detection/sentence/19-12-12-12-20',
    '../../results/echr/claim_detection/sentence/19-12-12-13-05',
    '../../results/echr/claim_detection/sentence/19-12-12-14-04',
    '../../results/echr/claim_detection/sentence/19-12-12-15-06',
    '../../results/echr/claim_detection/sentence/19-12-12-15-46',
    '../../results/echr/claim_detection/sentence/19-12-12-16-30',
    '../../results/echr/claim_detection/sentence/19-12-12-17-22',
    '../../results/echr/claim_detection/sentence/19-12-12-18-21',
    '../../results/echr/claim_detection/sentence/19-12-12-19-12',
    '../../results/echr/claim_detection/sentence/19-12-12-19-59',
    '../../results/echr/claim_detection/sentence/19-12-12-20-34',
    '../../results/echr/claim_detection/sentence/19-12-12-21-34',
    '../../results/echr/claim_detection/sentence/19-12-12-22-28',
    '../../results/echr/claim_detection/sentence/19-12-12-23-03',
    '../../results/echr/claim_detection/sentence/19-12-13-00-06',
    '../../results/echr/claim_detection/sentence/19-12-13-00-54',
    '../../results/echr/claim_detection/sentence/19-12-13-01-39',
    '../../results/echr/claim_detection/sentence/19-12-13-02-28',
    '../../results/echr/claim_detection/sentence/19-12-13-03-21',
    '../../results/echr/claim_detection/sentence/19-12-13-04-07',
    '../../results/echr/claim_detection/sentence/19-12-13-05-19',
    '../../results/echr/claim_detection/sentence/19-12-13-06-48',
    '../../results/echr/claim_detection/sentence/19-12-13-08-10',
    '../../results/echr/claim_detection/sentence/19-12-13-09-32',
    '../../results/echr/claim_detection/sentence/19-12-13-10-45',
    '../../results/echr/claim_detection/sentence/19-12-13-11-52',
    '../../results/echr/claim_detection/sentence/19-12-13-13-05',
    '../../results/echr/claim_detection/sentence/19-12-13-14-39',
    '../../results/echr/claim_detection/sentence/19-12-13-16-07',
    '../../results/echr/claim_detection/sentence/19-12-13-17-21',
    '../../results/echr/claim_detection/sentence/19-12-13-18-38',
    '../../results/echr/claim_detection/sentence/19-12-13-19-55',
    '../../results/echr/claim_detection/sentence/19-12-13-21-03',
    '../../results/echr/claim_detection/sentence/19-12-13-22-35',
]

# %% [markdown]
# ## Classification Results

# %%
echr_extra_keys = {
    'Partition': lambda prediction_file: re.search('.*partition(\d+).*', prediction_file).group(1)
}

# %%
cc_results = performance_metrics.architecture_metrics(CC_EXPERIMENTS_DIRS, keys=echr_extra_keys)
cc_results
# Out:
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
# DEBUG: classes used ['O' 'I-claim' 'I-premise']
#         Classifier Dataset  Accuracy  Precision    Recall  F1-Score Support  \
# 0   19-12-12-11-36    test  0.612006   0.640665  0.634837  0.604677    4781
# 1   19-12-12-11-36     dev  0.700383   0.702318  0.673015  0.681518    3134
# 2   19-12-12-11-36     dev  0.724574   0.721150  0.726065  0.715386    2291
# 3   19-12-12-11-36    test  0.562427   0.589227  0.550747  0.546119    2571
# 4   19-12-12-11-36    test  0.414947   0.487942  0.504366  0.390464    2810
# 5   19-12-12-11-36     dev  0.674856   0.676298  0.651851  0.659405    3134
# 6   19-12-12-11-36    test  0.700131   0.706337  0.689676  0.672760    2291
# 7   19-12-12-11-36     dev  0.583042   0.598358  0.587247  0.580791    2571
# 0   19-12-12-12-20    test  0.544924   0.550585  0.537361  0.531318    2571
# 1   19-12-12-12-20     dev  0.696873   0.690835  0.683557  0.686727    3134
# 2   19-12-12-12-20     dev  0.553870   0.562461  0.550027  0.550407    2571
# 3   19-12-12-12-20    test  0.605313   0.656864  0.640360  0.597332    4781
# 4   19-12-12-12-20     dev  0.692087   0.683512  0.689360  0.686096    3134
# 5   19-12-12-12-20    test  0.685727   0.683326  0.674037  0.664959    2291
# 6   19-12-12-12-20     dev  0.690965   0.681386  0.684241  0.682129    2291
# 7   19-12-12-12-20    test  0.394662   0.458638  0.467223  0.377111    2810
# 0   19-12-12-13-05    test  0.555037   0.571770  0.547382  0.545514    2571
# 1   19-12-12-13-05    test  0.585024   0.638769  0.629281  0.581647    4781
# 2   19-12-12-13-05     dev  0.626037   0.605820  0.603051  0.596569    3134
# 3   19-12-12-13-05     dev  0.687036   0.689090  0.690533  0.677103    2291
# 4   19-12-12-13-05     dev  0.649649   0.654278  0.619318  0.628131    3134
# 5   19-12-12-13-05     dev  0.594710   0.601847  0.589425  0.586957    2571
# 6   19-12-12-13-05    test  0.635967   0.637166  0.626420  0.608091    2291
# 7   19-12-12-13-05    test  0.415658   0.518938  0.524382  0.395585    2810
# 0   19-12-12-14-04    test  0.493238   0.566678  0.552660  0.440887    2810
# 1   19-12-12-14-04     dev  0.576429   0.578155  0.585736  0.576451    2571
# 2   19-12-12-14-04     dev  0.690491   0.695249  0.670559  0.679491    3134
# 3   19-12-12-14-04    test  0.633784   0.637038  0.615870  0.606637    2291
# 4   19-12-12-14-04    test  0.596737   0.649640  0.638461  0.590549    4781
# 5   19-12-12-14-04     dev  0.724138   0.715642  0.720813  0.715477    2291
# ..             ...     ...       ...        ...       ...       ...     ...
# 2   19-12-13-18-38     dev  0.515753   0.523694  0.504165  0.508046    2571
# 3   19-12-13-18-38     dev  0.604340   0.587901  0.581162  0.583593    3134
# 4   19-12-13-18-38     dev  0.607595   0.605067  0.591760  0.587427    2291
# 5   19-12-13-18-38    test  0.551349   0.538142  0.541243  0.531653    4781
# 6   19-12-13-18-38     dev  0.494257   0.477174  0.466505  0.469056    3134
# 7   19-12-13-18-38    test  0.546869   0.559078  0.535313  0.530552    2571
# 0   19-12-13-19-55    test  0.521230   0.573153  0.571515  0.521043    4781
# 1   19-12-13-19-55     dev  0.597320   0.584534  0.585105  0.584215    3134
# 2   19-12-13-19-55     dev  0.536367   0.550219  0.534536  0.538167    2571
# 3   19-12-13-19-55    test  0.491249   0.498842  0.485280  0.472375    2571
# 4   19-12-13-19-55    test  0.459786   0.526539  0.531570  0.445452    2810
# 5   19-12-13-19-55    test  0.578787   0.636318  0.594510  0.577394    2291
# 6   19-12-13-19-55     dev  0.609445   0.603816  0.581724  0.588786    3134
# 7   19-12-13-19-55     dev  0.607595   0.608269  0.609936  0.602970    2291
# 0   19-12-13-21-03    test  0.517794   0.524790  0.560302  0.495593    2810
# 1   19-12-13-21-03     dev  0.512125   0.512682  0.517525  0.501554    3134
# 2   19-12-13-21-03     dev  0.576040   0.593682  0.562340  0.569856    2571
# 3   19-12-13-21-03    test  0.549542   0.556287  0.534820  0.523653    2291
# 4   19-12-13-21-03     dev  0.556477   0.547077  0.552646  0.548935    3134
# 5   19-12-13-21-03     dev  0.601048   0.593670  0.591307  0.581648    2291
# 6   19-12-13-21-03    test  0.566409   0.583332  0.585305  0.559488    4781
# 7   19-12-13-21-03    test  0.493971   0.515592  0.491167  0.482104    2571
# 0   19-12-13-22-35     dev  0.642078   0.699706  0.651508  0.625841    2291
# 1   19-12-13-22-35     dev  0.576899   0.567952  0.563258  0.565275    3134
# 2   19-12-13-22-35    test  0.552703   0.554771  0.548854  0.551182    2571
# 3   19-12-13-22-35    test  0.592763   0.603649  0.575503  0.571517    4781
# 4   19-12-13-22-35    test  0.560454   0.613449  0.567165  0.548560    2291
# 5   19-12-13-22-35    test  0.472242   0.511223  0.522112  0.451730    2810
# 6   19-12-13-22-35     dev  0.572929   0.583835  0.566433  0.570747    2571
# 7   19-12-13-22-35     dev  0.609764   0.621932  0.610714  0.605297    3134
#
#    Partition
# 0          2
# 1          6
# 2          2
# 3          4
# 4          0
# 5          4
# 6          6
# 7          0
# 0          4
# 1          4
# 2          0
# 3          2
# 4          6
# 5          6
# 6          2
# 7          0
# 0          4
# 1          2
# 2          6
# 3          2
# 4          4
# 5          0
# 6          6
# 7          0
# 0          0
# 1          0
# 2          4
# 3          6
# 4          2
# 5          2
# ..       ...
# 2          0
# 3          4
# 4          2
# 5          2
# 6          6
# 7          4
# 0          2
# 1          4
# 2          0
# 3          4
# 4          0
# 5          6
# 6          6
# 7          2
# 0          0
# 1          4
# 2          0
# 3          6
# 4          6
# 5          2
# 6          2
# 7          4
# 0          2
# 1          6
# 2          4
# 3          2
# 4          6
# 5          0
# 6          0
# 7          4
#
# [280 rows x 8 columns]

# %%
# Only ECHR

cc_results_dev = cc_results.groupby(['Classifier', 'Dataset']).agg('mean').reset_index()
cc_results_dev[cc_results_dev.Dataset == 'dev']
# Out:
#         Classifier Dataset  Accuracy  Precision    Recall  F1-Score
# 0   19-12-12-11-36     dev  0.670714   0.674531  0.659545  0.659275
# 2   19-12-12-12-20     dev  0.658449   0.654548  0.651796  0.651340
# 4   19-12-12-13-05     dev  0.639358   0.637759  0.625582  0.622190
# 6   19-12-12-14-04     dev  0.666798   0.665599  0.662210  0.660949
# 8   19-12-12-15-06     dev  0.657850   0.657527  0.646970  0.649777
# 10  19-12-12-15-46     dev  0.635907   0.649992  0.638433  0.631052
# 12  19-12-12-16-30     dev  0.643701   0.648564  0.620896  0.622552
# 14  19-12-12-17-22     dev  0.637829   0.637746  0.636621  0.632942
# 16  19-12-12-18-21     dev  0.643583   0.644854  0.632299  0.632708
# 18  19-12-12-19-12     dev  0.618560   0.622303  0.605974  0.603794
# 20  19-12-12-19-59     dev  0.649649   0.643265  0.641803  0.639675
# 22  19-12-12-20-34     dev  0.653130   0.653340  0.645937  0.642930
# 24  19-12-12-21-34     dev  0.618982   0.614651  0.620774  0.611991
# 26  19-12-12-22-28     dev  0.620427   0.618751  0.620379  0.617997
# 28  19-12-12-23-03     dev  0.637331   0.632959  0.628875  0.628137
# 30  19-12-13-00-06     dev  0.594326   0.595005  0.581545  0.582573
# 32  19-12-13-00-54     dev  0.639978   0.637814  0.626421  0.625880
# 34  19-12-13-01-39     dev  0.601194   0.602373  0.600598  0.595861
# 36  19-12-13-02-28     dev  0.633371   0.627775  0.622885  0.623054
# 38  19-12-13-03-21     dev  0.620413   0.620603  0.613487  0.613084
# 40  19-12-13-04-07     dev  0.606371   0.598438  0.593953  0.588828
# 42  19-12-13-05-19     dev  0.588347   0.586610  0.581628  0.581765
# 44  19-12-13-06-48     dev  0.565718   0.565600  0.565968  0.560917
# 46  19-12-13-08-10     dev  0.606900   0.610923  0.605973  0.601571
# 48  19-12-13-09-32     dev  0.579413   0.575698  0.571076  0.567896
# 50  19-12-13-10-45     dev  0.649836   0.656289  0.638344  0.640292
# 52  19-12-13-11-52     dev  0.651559   0.654936  0.646715  0.645414
# 54  19-12-13-13-05     dev  0.658701   0.654653  0.643914  0.645922
# 56  19-12-13-14-39     dev  0.645675   0.654171  0.633275  0.631608
# 58  19-12-13-16-07     dev  0.641687   0.641842  0.634162  0.633442
# 60  19-12-13-17-21     dev  0.550051   0.537618  0.543048  0.539413
# 62  19-12-13-18-38     dev  0.555486   0.548459  0.535898  0.537030
# 64  19-12-13-19-55     dev  0.587682   0.586709  0.577825  0.578534
# 66  19-12-13-21-03     dev  0.561423   0.561778  0.555954  0.550498
# 68  19-12-13-22-35     dev  0.600417   0.618356  0.597978  0.591790

# %% [markdown]
# ### Comparison between classifiers

# %%
sns.catplot(data=cc_results,
            x='Classifier', kind='box', y='F1-Score', hue='Dataset',
            aspect=4, height=5, color=colors.green)

# %%
cc_results_stacked_metrics = cc_results.drop(columns='Support').set_index(
    ['Classifier', 'Dataset', 'Partition']).stack().reset_index().rename(
    columns={0: 'Metric Value', 'level_3': 'Metric'})

# %%
sns.catplot(data=cc_results_stacked_metrics[cc_results_stacked_metrics.Dataset == 'dev'],
            x='Classifier', kind='box', y='Metric Value', row='Metric',
            aspect=4, height=3, color=colors.red)

# %% [markdown]
# ## Learning rate

# %%
cc_learning = learning_metrics.architecture_learning(CC_EXPERIMENTS_DIRS, keys=echr_extra_keys)
cc_learning[:4]
# Out:
#    epoch Dataset  Metric Value      Classifier Partition
# 0      1     dev      0.541158  19-10-10-19-02         0
# 1      1    test      0.799640  19-10-10-19-02         0
# 2      2     dev      0.561205  19-10-10-19-02         0
# 3      2    test      0.807196  19-10-10-19-02         0

# %%
fig, ax = plt.subplots(figsize=(15, 8))
sns.pointplot(data=cc_learning[(cc_learning.Classifier == '19-10-10-19-02') & (cc_learning.Partition == '0')],
              x='epoch', y='Metric Value', hue='Dataset',
              aspect=6, join=True,
              color=colors.red, ax=ax)
# Set xticks every 5 elements
labels = ax.get_xticklabels() # get x labels
for i,l in enumerate(labels):
    if(i%5 != 0): labels[i] = '' # skip even labels
ax.set_xticklabels(labels); # set new labels

# %% [markdown]
# ### Confusion matrix

# %%
print(CC_EXPERIMENTS_DIRS[8])
# Out:
# ../../results/echr/claim_detection/paragraph/19-10-11-05-13

# %%
performance_metrics.plot_confusion_matrix(CC_EXPERIMENTS_DIRS[8], partition=0)
# Out:
#               precision    recall  f1-score   support
#
#      I-claim       0.52      0.53      0.52       838
#            O       0.77      0.77      0.77      1733
#
#    micro avg       0.69      0.69      0.69      2571
#    macro avg       0.65      0.65      0.65      2571
# weighted avg       0.69      0.69      0.69      2571

# %% [markdown]
# ---
#
# # Classifier variance

# %%
hyperparameters = pandas.read_csv('../../results/echr_claim_detection_sentence.tsv', sep='\t')
hyperparameters = hyperparameters.rename(columns={'Name': 'Classifier'})
hyperparameters['Attention type'] = hyperparameters['Attention type'].replace('None', 'No attention')
hyperparameters['Activation'] = hyperparameters['Activation'].replace('None', 'na')
hyperparameters[:3]
# Out:
#        Classifier  Accuracy  Precision    Recall  F1-Score Attention type  \
# 0  19-12-12-11-36  0.670714   0.674531  0.659545  0.659275   No attention
# 1  19-12-12-12-20  0.658449   0.654548  0.651796  0.651340   No attention
# 2  19-12-12-13-05  0.639358   0.637759  0.625582  0.622190   No attention
#
#   Activation  Heads  Attention size       Config Labels Separation Char embed  \
# 0         na    NaN             NaN  Exploration  Claim   Sentence        cnn
# 1         na    NaN             NaN  Exploration  Claim   Sentence       None
# 2         na    NaN             NaN  Exploration  Claim   Sentence       lstm
#
#    Word emb  Char embed size Last layer  LSTM layer size  Dropout  Batch Size
# 0       NaN               16        CRF              200      0.2          30
# 1       NaN               32    Softmax               50      0.2          50
# 2       NaN               16        CRF               30      0.4         200

# %%
hyperparameters['Activation'].unique()
# Out:
# array(['na', 'sigmoid', 'linear', 'tanh'], dtype=object)

# %% [markdown]
# ## Comparing attention mechanisms

# %%
sns.catplot(data=hyperparameters, kind='boxen',
            y='F1-Score', x='Attention type', hue='Activation',
            height=8, aspect=1.3, legend_out=False, palette=visualizations.activation_palette)

# %%
hyperparameters['Attention type'].unique()
# Out:
# array(['No attention', 'Word Attention', 'Context Attention'],
#       dtype=object)

# %%
sns.catplot(data=hyperparameters, kind='boxen',
            y='F1-Score', x='Attention type',
            height=8, legend_out=False)#, palette=visualizations.att_palette)

# %%
sns.catplot(data=hyperparameters[hyperparameters.Config == 'Exploration'], kind='boxen',
            y='F1-Score', x='LSTM layer size',# hue='Time/Feature',
            height=8, legend_out=False, color=colors.blue)

# %%
sns.catplot(data=hyperparameters[hyperparameters.Config == 'Exploration'], kind='boxen',
            y='F1-Score', x='Last layer',
            height=8, legend_out=False, color=colors.blue)

# %%
sns.catplot(data=hyperparameters[hyperparameters.Config == 'Exploration'], kind='boxen',
            y='F1-Score', x='Char embed', hue='Attention type',
            height=8, legend_out=False)

# %%
sns.catplot(data=hyperparameters[hyperparameters.Config == 'Exploration'], kind='boxen',
            y='F1-Score', x='Batch Size', hue='Attention type',
            height=8, legend_out=False)
